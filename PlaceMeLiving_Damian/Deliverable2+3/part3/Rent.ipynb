# %%
import numpy as np
import pandas as pd
import math


data = pd.read_csv("dataMA6.csv")
print(data.shape)
print(data.columns.values)
data = data[data['INCTOT'] < 250000]

import seaborn as sns 
#X = pd.DataFrame(X,dtype=np.int)
# create a correlation matrix that measures the linear relationships between the variables
data2 = data[['RENT','CITY','SEX','AGE','SCHOOL','EDUC','EMPSTAT','INCTOT','MORTGAGE','KITCHEN','FRIDGE','FTOTINC','MARST','RACE', 'PHONE','CINETHH']]
correlation_matrix = data2.corr().round(2)
# annot = True to print the values inside the square
plt.figure(figsize=(16, 16))
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# (13844, 29)
# ['Unnamed: 0' 'YEAR' 'STATEFIP' 'CITY' 'CNTRY' 'MORTGAGE' 'RENT' 'RENTGRS'
#  'VACANCY' 'KITCHEN' 'FRIDGE' 'PHONE' 'CINETHH' 'FAMSIZE' 'SEX' 'AGE'
#  'MARST' 'RACE' 'RACED' 'CITIZEN' 'SCHOOL' 'EDUC' 'EDUCD' 'GRADEATT'
#  'GRADEATTD' 'EMPSTAT' 'EMPSTATD' 'INCTOT' 'FTOTINC']

# %%
import matplotlib.pyplot as plt
salary = data['INCTOT']


salary = np.where(data['INCTOT'].between(0,250000), data['INCTOT'], 0)
salary = np.sort(salary)
print(salary[-1])
plt.hist(salary, bins=30,  facecolor="blue", edgecolor="black", alpha=0.7)

plt.show()
# Out:
# 248400

# %%
r = data['RENT']


r = np.where(data['RENT'].between(0,10000), data['RENT'], 0)
r = np.sort(r)
print(r[-1])
plt.hist(r, bins=30,  facecolor="blue", edgecolor="black", alpha=0.7)

plt.show()
# Out:
# 3700

# %%
"""
data["RENT"] = np.where(data["RENT"].between(0,500), 0, data["RENT"])
data["RENT"] = np.where(data["RENT"].between(500,1000), 1, data["RENT"])
data["RENT"] = np.where(data["RENT"].between(1000,1500), 2, data["RENT"])
data["RENT"] = np.where(data["RENT"].between(1500,2000), 3, data["RENT"])
data["RENT"] = np.where(data["RENT"].between(2000,2500), 4, data["RENT"])
data["RENT"] = np.where(data["RENT"].between(2500,3000), 5, data["RENT"])
data["RENT"] = np.where(data["RENT"].between(3000,3500), 6, data["RENT"])
data["RENT"] = np.where(data["RENT"]>3500, 7, data["RENT"])
y=data["RENT"]
"""
data["RENT"] = np.where(data["RENT"].between(0,1300), 0, data["RENT"])
data["RENT"] = np.where(data["RENT"].between(1300,1900), 1, data["RENT"])
data["RENT"] = np.where(data["RENT"].between(1900,3000), 2, data["RENT"])
data["RENT"] = np.where(data["RENT"]>3000, 4, data["RENT"])
y=data["RENT"]

"""
data['INCTOT'] = np.where(data['INCTOT'].between(0,10000), 0, data['INCTOT'])
data['INCTOT'] = np.where(data['INCTOT'].between(10000,20000), 1, data['INCTOT'])
data['INCTOT'] = np.where(data['INCTOT'].between(20000,40000), 2, data['INCTOT'])
data['INCTOT'] = np.where(data['INCTOT'].between(40000,60000), 3, data['INCTOT'])
data['INCTOT'] = np.where(data['INCTOT'].between(60000,90000), 4, data['INCTOT'])
data['INCTOT'] = np.where(data['INCTOT'].between(100000,150000), 5, data['INCTOT'])
data['INCTOT'] = np.where(data['INCTOT'].between(150000,250000), 6, data['INCTOT'])
data['INCTOT'] = np.where(data['INCTOT']>250000, 7, data['INCTOT'])

"""
print(y.shape)
print(y.head(5))
#X = data[['CITY','SEX','AGE','SCHOOL','EDUC','EDUCD','GRADEATT','GRADEATTD','EMPSTAT','EMPSTATD','INCTOT','FTOTINC']]
#X = data[['CITY','SEX','AGE','SCHOOL','EDUC','GRADEATT','EMPSTAT','INCTOT']]
#X = data[['CITY','SEX','AGE','SCHOOL','EDUC','EMPSTAT','INCTOT','MORTGAGE','KITCHEN','FRIDGE'，'FTOTINC']]
#X = data[['CITY','SEX','AGE','SCHOOL','EMPSTAT','INCTOT','MORTGAGE','KITCHEN','FRIDGE']]
X = data[['CITY','SEX','AGE','SCHOOL','EDUC','EMPSTAT','INCTOT','MORTGAGE','KITCHEN','FRIDGE','FTOTINC','MARST','RACE', 'PHONE','CINETHH']]
print(X.shape)
X['CITY'] = X['CITY'].replace(870, 1)
X['CITY'] = X['CITY'].replace(810, 0)
X['CITY'] = X['CITY'].replace(930, 2)
print(X.head(5))
# Out:
# (13688,)
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: RENT, dtype: int64
# (13688, 15)
#    CITY  SEX  AGE  SCHOOL  EDUC  EMPSTAT  INCTOT  MORTGAGE  KITCHEN  FRIDGE  \
# 0     0    1   32       1    11        1   86000         0        4       2
# 1     0    2   31       1    11        1   95000         0        4       2
# 2     0    1   31       1     6        1   55000         0        4       2
# 3     0    1   38       1     2        1   13200         0        4       2
# 4  6670    2   31       1     5        3       0         0        4       2
#
#    FTOTINC  MARST  RACE  PHONE  CINETHH
# 0   181000      1     4      2        1
# 1   181000      1     4      2        1
# 2    55000      6     1      2        1
# 3    13200      3     1      2        1
# 4    20500      1     7      2        1
# F:\anaconda\lib\site-packages\ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# F:\anaconda\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# F:\anaconda\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()


scaler = StandardScaler()
X = scaler.fit_transform(X)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# linear regression
from sklearn.linear_model import LinearRegression

reg = LinearRegression().fit(X_train, y_train)
print(reg.score(X_train, y_train))
pred = reg.predict(X_test)

print(pred[:5])
print(y_test[:5])
score = sum((pred-y_test)**2)
print(score)
# Out:
# 0.378428109690535
# [ 0.71483646 -0.80518175  0.47141951  1.46156189  2.89633684]
# 4146     0
# 9290     0
# 456      0
# 11746    4
# 9472     4
# Name: RENT, dtype: int64
# 1179.090003887982

# %%
# Logistic regression
from sklearn.linear_model import LogisticRegression

reg = LogisticRegression(solver="sag", max_iter=100000, multi_class="multinomial").fit(X_train, y_train)
print(reg.score(X_train, y_train))
pred = reg.predict(X_test)
print(pred[:10])
print(y_test[:10].values)
score = (pred==y_test).astype(int).mean()
print(score)
# Out:
# 0.6334929783261628
# [0 0 0 2 4 0 2 0 2 2]
# [0 0 0 4 4 0 2 2 2 0]
# 0.5953250547845143

# %%
# random forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=500, random_state=1, n_jobs=-1)
rf.fit(X_train, y_train)
print(rf.score(X_train, y_train))
pred = rf.predict(X_test)
print(pred[:10])
print(y_test[:10].values)
score = (pred==y_test).astype(int).mean()
print(score)
# Out:
# 0.9849013718645994
# [0 0 0 2 4 0 2 1 2 2]
# [0 0 0 4 4 0 2 2 2 0]
# 0.6172388604821037

# %%
#networks
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(20,30), random_state=1, max_iter=10000) 
clf.fit(X_train, y_train)
print(clf.score(X_train, y_train))
pred = clf.predict(X_test)
print(pred[:5])
print(y_test[:5])
score = (pred==y_test).astype(int).mean()
print(score)
# Out:
# 0.6790323889926131
# [0 0 0 2 4]
# 4146     0
# 9290     0
# 456      0
# 11746    4
# 9472     4
# Name: RENT, dtype: int64
# 0.5931336742147553

# %%
print(pred[:10])
print(y_test[:10].values)
# Out:
# [0 0 0 2 4 0 2 1 2 0]
# [0 0 0 4 4 0 2 2 2 0]

# %%
from sklearn.svm import SVC

clf = SVC(gamma='auto',C =1.5,break_ties=True)
clf.fit(X_train, y_train)
print(clf.score(X_train, y_train))
pred = clf.predict(X_test)
print(pred[:5])
print(y_test[:5])
score = (pred==y_test).astype(int).mean()
print(score)
# Out:
# 0.6522445003652894
# [0 0 0 2 4]
# 4146     0
# 9290     0
# 456      0
# 11746    4
# 9472     4
# Name: RENT, dtype: int64
# 0.6092037983929875

# %%
from sklearn.svm import LinearSVC

clf = LinearSVC(C =3,max_iter=100000)
clf.fit(X_train, y_train)
print(clf.score(X_train, y_train))
pred = clf.predict(X_test)
print(pred[:5])
print(y_test[:5])
score = (pred==y_test).astype(int).mean()
print(score)
# Out:
# 0.6340612062667424
# [0 0 0 2 2]
# 4146     0
# 9290     0
# 456      0
# 11746    4
# 9472     4
# Name: RENT, dtype: int64
# 0.5997078159240321

# %%
from sklearn.neighbors import KNeighborsClassifier

def knn(X_train,X_test,y_train,y_test,k):
    """knn to train and return accuracy"""
    #scaler = StandardScaler()
    #X_train = scaler.fit_transform(X_train)
    #X_test = scaler.fit_transform(X_test)
    model = KNeighborsClassifier(n_neighbors=k, n_jobs=-1)
    model.fit(X_train,y_train)
    pred = model.predict(X_train)
    train_acc = (pred==y_train).astype(int).mean()
    pred = model.predict(X_test)
    test_acc = (pred==y_test).astype(int).mean()
    print("k="+ str(k))
    print("train accuracy="+ str(train_acc))
    print("test accuracy="+ str(test_acc))
    return train_acc,test_acc

for i in range(10,150):
    knn(X_train,X_test,y_train,y_test,i)
    
    
model = KNeighborsClassifier(n_neighbors=62, n_jobs=-1)
model.fit(X_train,y_train)
pred6 = model.predict(X_train)
train_acc = (pred6==y_train).astype(int).mean()
pred7 = model.predict(X_test)
test_acc = (pred7==y_test).astype(int).mean()
print(test_acc)
# Out:
# k=10
# train accuracy=0.6780582839516195
# test accuracy=0.5953250547845143
# k=11
# train accuracy=0.6742430392077279
# test accuracy=0.589481373265157
# k=12
# train accuracy=0.6707524961441675
# test accuracy=0.5924032140248356
# k=13
# train accuracy=0.6676678301810212
# test accuracy=0.6018991964937911
# k=14
# train accuracy=0.6645831642178748
# test accuracy=0.6018991964937911
# k=15
# train accuracy=0.6650702167383716
# test accuracy=0.6004382761139518
# k=16
# train accuracy=0.6613361474145629
# test accuracy=0.6011687363038715
# k=17
# train accuracy=0.6594691127526585
# test accuracy=0.6040905770635501
# k=18
# train accuracy=0.6567091484698433
# test accuracy=0.6084733382030679
# k=19
# train accuracy=0.6559785696890982
# test accuracy=0.6055514974433893
# k=20
# train accuracy=0.6549232892280218
# test accuracy=0.6018991964937911
# k=21
# train accuracy=0.6545985875476905
# test accuracy=0.5945945945945946
# k=22
# train accuracy=0.6535433070866141
# test accuracy=0.6004382761139518
# k=23
# train accuracy=0.6520821495251238
# test accuracy=0.5975164353542732
# k=24
# train accuracy=0.6494845360824743
# test accuracy=0.5997078159240321
# k=25
# train accuracy=0.6508645182238818
# test accuracy=0.5975164353542732
# k=26
# train accuracy=0.6490786589820602
# test accuracy=0.6033601168736303
# k=27
# train accuracy=0.6470492734799903
# test accuracy=0.5953250547845143
# k=28
# train accuracy=0.6453445896582515
# test accuracy=0.5997078159240321
# k=29
# train accuracy=0.644695186297589
# test accuracy=0.6011687363038715
# k=30
# train accuracy=0.6450198879779203
# test accuracy=0.5967859751643535
# k=31
# train accuracy=0.6431528533160159
# test accuracy=0.6011687363038715
# k=32
# train accuracy=0.6451010633980031
# test accuracy=0.6011687363038715
# k=33
# train accuracy=0.6439646075168439
# test accuracy=0.6011687363038715
# k=34
# train accuracy=0.6440457829369267
# test accuracy=0.6004382761139518
# k=35
# train accuracy=0.6439646075168439
# test accuracy=0.5967859751643535
# k=36
# train accuracy=0.6443704846172579
# test accuracy=0.5953250547845143
# k=37
# train accuracy=0.644695186297589
# test accuracy=0.5931336742147553
# k=38
# train accuracy=0.6448575371377547
# test accuracy=0.5967859751643535
# k=39
# train accuracy=0.6438834320967611
# test accuracy=0.5960555149744339
# k=40
# train accuracy=0.6429093270557675
# test accuracy=0.5967859751643535
# k=41
# train accuracy=0.6429905024758503
# test accuracy=0.5982468955441929
# k=42
# train accuracy=0.6420975728549395
# test accuracy=0.5982468955441929
# k=43
# train accuracy=0.6414481694942772
# test accuracy=0.6018991964937911
# k=44
# train accuracy=0.63949995941229
# test accuracy=0.5953250547845143
# k=45
# train accuracy=0.6396623102524556
# test accuracy=0.5989773557341125
# k=46
# train accuracy=0.6398246610926211
# test accuracy=0.6033601168736303
# k=47
# train accuracy=0.6394187839922072
# test accuracy=0.6055514974433893
# k=48
# train accuracy=0.6397434856725384
# test accuracy=0.5989773557341125
# k=49
# train accuracy=0.6388505560516275
# test accuracy=0.6026296566837107
# k=50
# train accuracy=0.6389317314717103
# test accuracy=0.6033601168736303
# k=51
# train accuracy=0.6373893984901372
# test accuracy=0.5997078159240321
# k=52
# train accuracy=0.6382011526909652
# test accuracy=0.5975164353542732
# k=53
# train accuracy=0.6367399951294748
# test accuracy=0.6018991964937911
# k=54
# train accuracy=0.6369835213897231
# test accuracy=0.5982468955441929
# k=55
# train accuracy=0.63747057391022
# test accuracy=0.6018991964937911
# k=56
# train accuracy=0.6367399951294748
# test accuracy=0.6011687363038715
# k=57
# train accuracy=0.6369835213897231
# test accuracy=0.6033601168736303
# k=58
# train accuracy=0.6352788375679844
# test accuracy=0.6026296566837107
# k=59
# train accuracy=0.6364964688692264
# test accuracy=0.6004382761139518
# k=60
# train accuracy=0.6364152934491436
# test accuracy=0.6004382761139518
# k=61
# train accuracy=0.6363341180290608
# test accuracy=0.6018991964937911
# k=62
# train accuracy=0.6367399951294748
# test accuracy=0.5989773557341125
# k=63
# train accuracy=0.6369023459696403
# test accuracy=0.6011687363038715
# k=64
# train accuracy=0.6351976621479016
# test accuracy=0.5989773557341125
# k=65
# train accuracy=0.635035311307736
# test accuracy=0.5982468955441929
# k=66
# train accuracy=0.636252942608978
# test accuracy=0.6011687363038715
# k=67
# train accuracy=0.6353600129880672
# test accuracy=0.6048210372534697
# k=68
# train accuracy=0.6341423816868252
# test accuracy=0.6004382761139518
# k=69
# train accuracy=0.6337365045864113
# test accuracy=0.5975164353542732
# k=70
# train accuracy=0.6341423816868252
# test accuracy=0.5989773557341125
# k=71
# train accuracy=0.6349541358876533
# test accuracy=0.5989773557341125
# k=72
# train accuracy=0.6352788375679844
# test accuracy=0.5953250547845143
# k=73
# train accuracy=0.6352788375679844
# test accuracy=0.5960555149744339
# k=74
# train accuracy=0.6369835213897231
# test accuracy=0.5924032140248356
# k=75
# train accuracy=0.637064696809806
# test accuracy=0.5938641344046749
# k=76
# train accuracy=0.636658819709392
# test accuracy=0.5960555149744339
# k=77
# train accuracy=0.636252942608978
# test accuracy=0.5967859751643535
# k=78
# train accuracy=0.6355223638282328
# test accuracy=0.5975164353542732
# k=79
# train accuracy=0.6348729604675705
# test accuracy=0.5975164353542732
# k=80
# train accuracy=0.6356847146683984
# test accuracy=0.5938641344046749
# k=81
# train accuracy=0.6348729604675705
# test accuracy=0.5975164353542732
# k=82
# train accuracy=0.6337365045864113
# test accuracy=0.5975164353542732
# k=83
# train accuracy=0.6332494520659144
# test accuracy=0.5989773557341125
# k=84
# train accuracy=0.6343047325269908
# test accuracy=0.5967859751643535
# k=85
# train accuracy=0.6339800308466597
# test accuracy=0.5975164353542732
# k=86
# train accuracy=0.6332494520659144
# test accuracy=0.5960555149744339
# k=87
# train accuracy=0.6331682766458316
# test accuracy=0.5960555149744339
# k=88
# train accuracy=0.6334929783261628
# test accuracy=0.5960555149744339
# k=89
# train accuracy=0.6331682766458316
# test accuracy=0.5938641344046749
# k=90
# train accuracy=0.6330059258056661
# test accuracy=0.5945945945945946
# k=91
# train accuracy=0.6330059258056661
# test accuracy=0.5953250547845143
# k=92
# train accuracy=0.6327623995454177
# test accuracy=0.5953250547845143
# k=93
# train accuracy=0.6318694699245069
# test accuracy=0.5953250547845143
# k=94
# train accuracy=0.6318694699245069
# test accuracy=0.5967859751643535
# k=95
# train accuracy=0.6324376978650864
# test accuracy=0.5945945945945946
# k=96
# train accuracy=0.6328435749655005
# test accuracy=0.5924032140248356
# k=97
# train accuracy=0.6322753470249208
# test accuracy=0.5945945945945946
# k=98
# train accuracy=0.6326000487052521
# test accuracy=0.5953250547845143
# k=99
# train accuracy=0.6314635928240928
# test accuracy=0.5945945945945946
# k=100
# train accuracy=0.6320318207646725
# test accuracy=0.5931336742147553
# k=101
# train accuracy=0.6324376978650864
# test accuracy=0.5945945945945946
# k=102
# train accuracy=0.6315447682441757
# test accuracy=0.5924032140248356
# k=103
# train accuracy=0.6318694699245069
# test accuracy=0.5938641344046749
# k=104
# train accuracy=0.6317071190843413
# test accuracy=0.5975164353542732
# k=105
# train accuracy=0.6321129961847552
# test accuracy=0.5945945945945946
# k=106
# train accuracy=0.6322753470249208
# test accuracy=0.5967859751643535
# k=107
# train accuracy=0.6321129961847552
# test accuracy=0.5924032140248356
# k=108
# train accuracy=0.6313012419839272
# test accuracy=0.591672753834916
# k=109
# train accuracy=0.6317882945044241
# test accuracy=0.5924032140248356
# k=110
# train accuracy=0.6305706632031821
# test accuracy=0.589481373265157
# k=111
# train accuracy=0.6307330140433477
# test accuracy=0.5902118334550767
# k=112
# train accuracy=0.6295965581621885
# test accuracy=0.591672753834916
# k=113
# train accuracy=0.6302459615228508
# test accuracy=0.589481373265157
# k=114
# train accuracy=0.6300024352626025
# test accuracy=0.5902118334550767
# k=115
# train accuracy=0.6305706632031821
# test accuracy=0.5902118334550767
# k=116
# train accuracy=0.6304083123630165
# test accuracy=0.5902118334550767
# k=117
# train accuracy=0.6308953648835133
# test accuracy=0.591672753834916
# k=118
# train accuracy=0.6300024352626025
# test accuracy=0.587289992695398
# k=119
# train accuracy=0.6297589090023541
# test accuracy=0.589481373265157
# k=120
# train accuracy=0.6289471548015261
# test accuracy=0.5924032140248356
# k=121
# train accuracy=0.6290283302216089
# test accuracy=0.5902118334550767
# k=122
# train accuracy=0.6297589090023541
# test accuracy=0.591672753834916
# k=123
# train accuracy=0.6287036285412777
# test accuracy=0.5924032140248356
# k=124
# train accuracy=0.6290283302216089
# test accuracy=0.5909422936449964
# k=125
# train accuracy=0.6290283302216089
# test accuracy=0.5931336742147553
# k=126
# train accuracy=0.6287848039613605
# test accuracy=0.591672753834916
# k=127
# train accuracy=0.6299212598425197
# test accuracy=0.5909422936449964
# k=128
# train accuracy=0.6305706632031821
# test accuracy=0.5931336742147553
# k=129
# train accuracy=0.6307330140433477
# test accuracy=0.5931336742147553
# k=130
# train accuracy=0.6304894877830993
# test accuracy=0.5931336742147553
# k=131
# train accuracy=0.6297589090023541
# test accuracy=0.5931336742147553
# k=132
# train accuracy=0.6298400844224369
# test accuracy=0.589481373265157
# k=133
# train accuracy=0.6300836106826853
# test accuracy=0.591672753834916
# k=134
# train accuracy=0.6296777335822713
# test accuracy=0.589481373265157
# k=135
# train accuracy=0.6300024352626025
# test accuracy=0.587289992695398
# k=136
# train accuracy=0.6295965581621885
# test accuracy=0.5909422936449964
# k=137
# train accuracy=0.6303271369429336
# test accuracy=0.587289992695398
# k=138
# train accuracy=0.6300836106826853
# test accuracy=0.5880204528853178
# k=139
# train accuracy=0.6299212598425197
# test accuracy=0.5887509130752374
# k=140
# train accuracy=0.6306518386232649
# test accuracy=0.5887509130752374
# k=141
# train accuracy=0.6298400844224369
# test accuracy=0.5887509130752374
# k=142
# train accuracy=0.6293530319019401
# test accuracy=0.5909422936449964
# k=143
# train accuracy=0.6291095056416917
# test accuracy=0.591672753834916
# k=144
# train accuracy=0.6288659793814433
# test accuracy=0.5887509130752374
# k=145
# train accuracy=0.6288659793814433
# test accuracy=0.5880204528853178
# k=146
# train accuracy=0.6291906810617744
# test accuracy=0.5902118334550767
# k=147
# train accuracy=0.6290283302216089
# test accuracy=0.5902118334550767
# k=148
# train accuracy=0.6289471548015261
# test accuracy=0.591672753834916
# k=149
# train accuracy=0.6289471548015261
# test accuracy=0.5887509130752374
# 0.5989773557341125
